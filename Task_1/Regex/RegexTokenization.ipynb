# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
import re

# %%
with open('/content/drive/MyDrive/wikitext-2/wikitext-2/wiki.train.tokens', 'r') as file:
    content1  = file.readlines()

with open('/content/drive/MyDrive/wikitext-2/wikitext-2/wiki.test.tokens', 'r') as file:
    content2  = file.readlines()

with open('/content/drive/MyDrive/wikitext-2/wikitext-2/wiki.valid.tokens', 'r') as file:
    content3  = file.readlines()

# %%
content = content1 + content2 + content3

# %%
# Regex Tokenization

def regex_tokenization(content):
  regex = r"\w+(?:'\w+)?|[^\w\s]"
  tokens = re.findall(regex, content)
  return tokens

# %%
regex_tokens = []

for line in content:
    temp_tokens = regex_tokenization(line)
    for element in temp_tokens:
      regex_tokens.append(element)
print(regex_tokens[0:100])
# Out:
# ['=', 'Valkyria', 'Chronicles', 'III', '=', 'Senjō', 'no', 'Valkyria', '3', ':', '<', 'unk', '>', 'Chronicles', '(', 'Japanese', ':', '戦場のヴァルキュリア3', ',', 'lit', '.', 'Valkyria', 'of', 'the', 'Battlefield', '3', ')', ',', 'commonly', 'referred', 'to', 'as', 'Valkyria', 'Chronicles', 'III', 'outside', 'Japan', ',', 'is', 'a', 'tactical', 'role', '@', '-', '@', 'playing', 'video', 'game', 'developed', 'by', 'Sega', 'and', 'Media', '.', 'Vision', 'for', 'the', 'PlayStation', 'Portable', '.', 'Released', 'in', 'January', '2011', 'in', 'Japan', ',', 'it', 'is', 'the', 'third', 'game', 'in', 'the', 'Valkyria', 'series', '.', '<', 'unk', '>', 'the', 'same', 'fusion', 'of', 'tactical', 'and', 'real', '@', '-', '@', 'time', 'gameplay', 'as', 'its', 'predecessors', ',', 'the', 'story', 'runs', 'parallel']

# %%
output_file_path = '/content/drive/MyDrive/NLPCoursework/Regex/regex_tokens.txt'

# %%
with open(output_file_path, 'w') as output_file:
    for token in regex_tokens:
        output_file.write(token + '\n')
